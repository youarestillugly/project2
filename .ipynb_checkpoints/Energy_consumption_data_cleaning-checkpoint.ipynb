# %% [markdown]
# # Energy Consumption Prediction

# %% [markdown]
# ## Data Loading

# %%
import pandas as pd

# %%
data = pd.read_csv("energy_consumption.csv")
data.head()
# Out:
#    Month  Hour DayOfWeek Holiday  Temperature  Humidity  SquareFootage  \
# 0      8    10    Sunday      No       23.951    44.511       1339.234
# 1      7     6  Saturday     Yes       25.341    33.366       1966.729
# 2      2    17   Tuesday     Yes       21.945    27.862       1150.873
# 3     12    12    Friday      No       25.131    63.267       1320.303
# 4     10    17    Friday     Yes       28.738    33.270       1950.890
#
#    Occupancy HVACUsage LightingUsage  RenewableEnergy  EnergyConsumption
# 0      4.158       Off            On           21.512             83.136
# 1      3.159        On            On            7.298             80.181
# 2      0.957       Off            On            6.695             80.972
# 3      5.174        On           Off           11.069             84.931
# 4      7.581       Off           Off           11.307             92.539

# %% [markdown]
# ## Initial Inspection

# %%
print(f"{data.info()}\n")     #Data Types and Missing Values
print(f"\nStatistical Summary:\n\n{data.describe()}\n")
print(f"\nRows and Columns: {data.shape}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127400 entries, 0 to 127399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Month              127400 non-null  int64
#  1   Hour               127400 non-null  int64
#  2   DayOfWeek          123752 non-null  object
#  3   Holiday            123702 non-null  object
#  4   Temperature        123659 non-null  float64
#  5   Humidity           123786 non-null  float64
#  6   SquareFootage      123702 non-null  float64
#  7   Occupancy          123710 non-null  float64
#  8   HVACUsage          123689 non-null  object
#  9   LightingUsage      123765 non-null  object
#  10  RenewableEnergy    123693 non-null  float64
#  11  EnergyConsumption  123751 non-null  float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 11.7+ MB
# None
#
#
# Statistical Summary:
#
#                Month           Hour    Temperature       Humidity  \
# count  127400.000000  127400.000000  123659.000000  123786.000000
# mean        6.259765      11.505950      24.937357      45.478235
# std         3.586459       6.872605       3.277236       9.244163
# min         1.000000       0.000000      16.145000      24.246000
# 25%         3.000000       6.000000      22.322000      38.053000
# 50%         6.000000      11.000000      24.804000      45.623500
# 75%         9.000000      18.000000      27.444000      52.787000
# max        12.000000      23.000000      35.405000      70.903000
#
#        SquareFootage      Occupancy  RenewableEnergy  EnergyConsumption
# count  123702.000000  123710.000000    123693.000000      123751.000000
# mean     1507.548370       4.565472        15.178766          76.731939
# std       302.738396       2.924440         9.194770           9.946940
# min       826.477000      -0.381000         0.005000          44.628000
# 25%      1252.558500       2.004000         7.432000          69.841000
# 50%      1509.178500       4.719000        15.282000          76.515000
# 75%      1754.533000       7.046000        22.885000          83.466000
# max      2363.861000      10.869000        34.884000         114.491000
#
#
# Rows and Columns: (127400, 12)

# %% [markdown]
# ## Fix Data Types

# %%
day_map = {
    'Monday': 0,
    'Tuesday': 1,
    'Wednesday': 2,
    'Thursday': 3,
    'Friday': 4,
    'Saturday': 5,
    'Sunday': 6
}

data['DayOfWeek'] = (
    data['DayOfWeek']
    .astype(str)
    .str.strip()
    .str.capitalize()
    .map(day_map)
)

# Fill safely
if data['DayOfWeek'].isnull().all():
    import numpy as np
    data['DayOfWeek'] = np.random.randint(0, 7, size=len(data))
else:
    data['DayOfWeek'] = data['DayOfWeek'].fillna(data['DayOfWeek'].mode()[0])

data['DayOfWeek'] = data['DayOfWeek'].astype(int)

# %%
# HVAC
data['HVACUsage'] = data['HVACUsage'].replace({'Off': 0, 'On': 1})
data['HVACUsage'] = pd.to_numeric(data['HVACUsage'], errors='coerce')
data['HVACUsage'] = data['HVACUsage'].fillna(data['HVACUsage'].mean())

# Lighting
data['LightingUsage'] = data['LightingUsage'].replace({'Off': 0, 'On': 1})
data['LightingUsage'] = pd.to_numeric(data['LightingUsage'], errors='coerce')
data['LightingUsage'] = data['LightingUsage'].fillna(data['LightingUsage'].mean())

# Holiday
data['Holiday'] = data['Holiday'].replace({'No': 0, 'Yes': 1})
data['Holiday'] = pd.to_numeric(data['Holiday'], errors='coerce')
data['Holiday'] = data['Holiday'].fillna(data['Holiday'].mode()[0])
data['Holiday'] = data['Holiday'].astype(int)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1792\2229957315.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['HVACUsage'] = data['HVACUsage'].replace({'Off': 0, 'On': 1})
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1792\2229957315.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['LightingUsage'] = data['LightingUsage'].replace({'Off': 0, 'On': 1})
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1792\2229957315.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Holiday'] = data['Holiday'].replace({'No': 0, 'Yes': 1})

# %% [markdown]
# ## Validate Ranges

# %%
data = data[(data['Month'] >= 1) & (data['Month'] <= 12)]
data = data[(data['Hour'] >= 0) & (data['Hour'] <= 23)]
data = data[(data['DayOfWeek'] >= 0) & (data['DayOfWeek'] <= 6)]

# %% [markdown]
# ## Check Missing Values

# %%
data.isnull().sum()
# Out:
# Month                   0
# Hour                    0
# DayOfWeek               0
# Holiday                 0
# Temperature          3741
# Humidity             3614
# SquareFootage        3698
# Occupancy            3690
# HVACUsage               0
# LightingUsage           0
# RenewableEnergy      3707
# EnergyConsumption    3649
# dtype: int64

# %% [markdown]
# ## Handle Missing Values

# %%
# Numerical columns → fill with mean
num_cols = data.select_dtypes(include=['float64','int64']).columns
data[num_cols] = data[num_cols].fillna(data[num_cols].mean())

# Categorical (Holiday)
data['Holiday'] = data['Holiday'].fillna(data['Holiday'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Month                0
# Hour                 0
# DayOfWeek            0
# Holiday              0
# Temperature          0
# Humidity             0
# SquareFootage        0
# Occupancy            0
# HVACUsage            0
# LightingUsage        0
# RenewableEnergy      0
# EnergyConsumption    0
# dtype: int64

# %% [markdown]
# ## Remove Duplicates

# %%
data = data.drop_duplicates()

# %% [markdown]
# ## Handle Outliers

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1

data = data[~((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ## Final Check

# %%
print(f"{data.info()}\n")     #Data Types and Missing Values
data.isnull().sum()
print(f"\nRows and Columns after cleaning: {data.shape}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124394 entries, 0 to 127399
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Month              124394 non-null  int64
#  1   Hour               124394 non-null  int64
#  2   DayOfWeek          124394 non-null  int64
#  3   Holiday            124394 non-null  int64
#  4   Temperature        124394 non-null  float64
#  5   Humidity           124394 non-null  float64
#  6   SquareFootage      124394 non-null  float64
#  7   Occupancy          124394 non-null  float64
#  8   HVACUsage          124394 non-null  float64
#  9   LightingUsage      124394 non-null  float64
#  10  RenewableEnergy    124394 non-null  float64
#  11  EnergyConsumption  124394 non-null  float64
# dtypes: float64(8), int64(4)
# memory usage: 12.3 MB
# None
#
#
# Rows and Columns after cleaning: (124394, 12)

# %% [markdown]
# ## Save Cleaned dataset

# %%
data.to_csv("cleaned_energy_dataset.csv", index=False)
